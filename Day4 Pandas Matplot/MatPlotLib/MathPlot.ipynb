# %%
import numpy  as np
import pandas as pd 
data=pd.read_csv('../Numpy/Data/1.csv')
data.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
import matplotlib.pyplot as plt

plt.hist(data['Store'],bins=9,range=(1,30))
# Out:
# (array([572., 429., 429., 429., 572., 429., 429., 429., 572.]),
#  array([ 1.        ,  4.22222222,  7.44444444, 10.66666667, 13.88888889,
#         17.11111111, 20.33333333, 23.55555556, 26.77777778, 30.        ]),
#  <BarContainer object of 9 artists>)

# %%
plt.xlabel('Store')
plt.ylabel("Temperature")
# Out:
# Text(0, 0.5, 'Temperature')
